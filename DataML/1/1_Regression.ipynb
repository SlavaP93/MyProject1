# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # для отрисовки 3D проекции

matplotlib.rc("font", size=18) # для увеличения шрифта подписей графиков

# %%
# загружаем данные
houses = pd.read_csv("1.4_houses.csv")

# %%
houses.head(7)
# Out:
#    dim_1  dim_2   level   price
# 0     29     28  luxury  2212.0
# 1     28     29  luxury  2203.0
# 2      6      9   basic   254.0
# 3      5      9   basic   242.0
# 4      6      6   basic   195.0
# 5      5      8   basic   200.0
# 6     27     29  luxury  2108.0

# %%
fig = plt.figure(figsize=(5, 5)) # создаем картинку
ax = plt.axes()

# помещаем точки на график
ax.scatter(houses["dim_1"], houses["price"], s=100)

# отображаем картинку
plt.show()

# %%
# импортируем модуль, отвечающий за линейную регрессию
from sklearn.linear_model import LinearRegression

# %%
# выгружаем признаки и целевые значения в отдельные переменные
X = houses[["dim_1"]]
y = houses["price"]

# создаем регрессор
reg = LinearRegression().fit(X, y)

# %%
# вытаскиваем нужные коэффициенты
[b] = reg.coef_
a = reg.intercept_

# создаем функцию для предсказания цены дома
def reg_prediction(dim_1):
    return a + b * dim_1

# %%
reg_prediction(X.dim_1[0])
# Out:
# 2057.887633711507

# %%
# используем встроенные методы для расчета предсказаний
reg.predict(X[0:1])[0]
# Out:
# 2057.887633711507

# %%
fig = plt.figure(figsize=(5, 6)) # создаем картинку
ax = plt.axes()

# помещаем точки на график
ax.scatter(houses["dim_1"], houses["price"], s=100)
# помещаем предсказания
ax.plot([X.dim_1.min(), X.dim_1.max()], [reg_prediction(X.dim_1.min()), reg_prediction(X.dim_1.max())], c="red")

# отображаем картинку
plt.show()

# %%
fig = plt.figure(figsize=(10, 10)) # создаем картинку
ax = plt.axes(projection="3d") # устанавливаем проекцию

# помещаем точки на график
ax.scatter(houses["dim_1"], houses["dim_2"], houses["price"], s=100)

# называем оси
ax.set_xlabel("dim_1")
ax.set_ylabel("dim_2")
ax.set_zlabel("price")

# отображаем картинку
plt.show()

# %%
# импортируем модуль, отвечающий за линейную регрессию
from sklearn.linear_model import LinearRegression

# %%
# выгружаем признаки и целевые значения в отдельные переменные
X = houses[["dim_1", "dim_2"]]
y = houses["price"]

# создаем регрессор
reg = LinearRegression().fit(X, y)

# %%
# price = price(dim_1, dim_2) = a + b1 * dim_1 + b2 * dim_2

# %%
# вытаскиваем нужные коэффициенты
[b1, b2] = reg.coef_
a = reg.intercept_

# создаем функцию для предсказания цены дома
def reg_prediction(dim_1, dim_2):
    return a + b1 * dim_1 + b2 * dim_2

# %%
reg_prediction(X.dim_1[0], X.dim_2[0])
# Out:
# 2080.82359179565

# %%
# используем встроенные методы для расчета предсказаний
reg.predict(X[0:1])[0]
# Out:
# 2080.82359179565

# %%
# сделаем предсказания для различных конфигураций домов
d1, d2 = list(), list()
for i1 in np.linspace(min(houses["dim_1"]), max(houses["dim_1"]), 100):
    for i2 in np.linspace(min(houses["dim_2"]), max(houses["dim_2"]), 100):
        d1.append(i2)
        d2.append(i2)
d1 = np.array(d1).reshape(-1, 1)
d2 = np.array(d2).reshape(-1, 1)
p = reg.predict(np.concatenate([d1, d2], axis=1))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
fig = plt.figure(figsize=(20, 20)) # создаем картинку
ax = plt.axes(projection="3d") # устанавливаем проекцию

# помещаем точки на график
ax.scatter(houses["dim_1"], houses["dim_2"], houses["price"], s=100)

# помещаем предсказанные значения на график
ax.plot_trisurf(d1.ravel(), d2.ravel(), p.ravel(), alpha=0.2)


# называем оси
ax.set_xlabel("dim_1")
ax.set_ylabel("dim_2")
ax.set_zlabel("price")


# изменяем позицию камеры и отрисовываем картинку
ax.elev = 27
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[46], line 8
#       5 ax.scatter(houses["dim_1"], houses["dim_2"], houses["price"], s=100)
#       7 # помещаем предсказанные значения на график
# ----> 8 ax.plot_trisurf(d1.ravel(), d2.ravel(), p.ravel(), alpha=0.2)
#      11 # называем оси
#      12 ax.set_xlabel("dim_1")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2003, in Axes3D.plot_trisurf(self, color, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1999 cmap = kwargs.get('cmap', None)
#    2000 shade = kwargs.pop('shade', cmap is None)
#    2002 tri, args, kwargs = \
# -> 2003     Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    2004 try:
#    2005     z = kwargs.pop('Z')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\tri\_triangulation.py:167, in Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#     164 else:
#     165     x, y, triangles, mask, args, kwargs = \
#     166         Triangulation._extract_triangulation_params(args, kwargs)
# --> 167     triangulation = Triangulation(x, y, triangles, mask)
#     168 return triangulation, args, kwargs
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\tri\_triangulation.py:60, in Triangulation.__init__(self, x, y, triangles, mask)
#      55 self.is_delaunay = False
#      57 if triangles is None:
#      58     # No triangulation specified, so use matplotlib._qhull to obtain
#      59     # Delaunay triangulation.
# ---> 60     self.triangles, self._neighbors = _qhull.delaunay(x, y, sys.flags.verbose)
#      61     self.is_delaunay = True
#      62 else:
#      63     # Triangulation specified. Copy, since we may correct triangle
#      64     # orientation.
#
# RuntimeError: Error in qhull Delaunay triangulation calculation: singular input data (exitcode=2); use python verbose option (-v) to see original qhull error.
